# %%
class car:
  def __init__(self,wheel,color,name):
    self.wheel = wheel
    self.color =color
    self.name = name

p = car(4,"blue","swift")
print(p.wheel)
print(p.color,p.name)
# Out:
# 4
# blue swift

# %%
class a:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def fn(zz):
    print("hello my name is ",zz.name,"my age is ",zz.age)

obj = a("shahell","100")
print(obj.name,obj.age)
obj.name = 'shahal'
obj.age = 20
print(obj.name,obj.age)
try:
  del obj.age
  print(obj.age)
except:
  print("age already deleted....")
# Out:
# shahell 100
# shahal 20
# age already deleted....
